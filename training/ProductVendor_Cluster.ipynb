# %% [markdown]
# # Customer
# Grouping customers in various ways to understand their behavior and preferences.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from common_functions import get_engine, read_data_return_df, drop_sk_datetime_added_columns as drop_columns
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances, silhouette_score
from sklearn.decomposition import PCA

# %% [markdown]
# ## Connecting to the Database

# %%
engine = get_engine()
# Out:
# Connection to UnitedOutdoors database successful

# %% [markdown]
# ## Reading in the Data

# %%
vendor_query = "SELECT * FROM ProductVendor"
vendors = read_data_return_df(vendor_query, engine)

vendors
# Out:
#      PRODUCTVENDOR_sk  PRODUCTVENDOR_PRODUCTVENDOR_ProductID  \
# 0                   1                                   1997
# 1                   2                                   1998
# 2                   3                                   2000
# 3                   4                                      6
# 4                   5                                      6
# ..                ...                                    ...
# 455               456                                   1614
# 456               457                                   1620
# 457               458                                   1626
# 458               459                                   1680
# 459               460                                   1704
#
#      PRODUCTVENDOR_PRODUCTVENDOR_BusinessEntityID  \
# 0                                             901
# 1                                             834
# 2                                             911
# 3                                             855
# 4                                             916
# ..                                            ...
# 455                                           833
# 456                                           886
# 457                                           819
# 458                                           854
# 459                                           832
#
#      PRODUCTVENDOR_PRODUCTVENDOR_AverageLeadTime  \
# 0                                             17
# 1                                             19
# 2                                             17
# 3                                             19
# 4                                             17
# ..                                           ...
# 455                                           16
# 456                                           15
# 457                                           17
# 458                                           19
# 459                                           19
#
#      PRODUCTVENDOR_PRODUCTVENDOR_StandardPrice  \
# 0                                        47.87
# 1                                        39.92
# 2                                        54.31
# 3                                        28.17
# 4                                        25.77
# ..                                         ...
# 455                                      45.99
# 456                                      59.99
# 457                                      59.99
# 458                                      78.89
# 459                                      14.99
#
#      PRODUCTVENDOR_PRODUCTVENDOR_LastReceiptCost  \
# 0                                        50.2635
# 1                                        41.9160
# 2                                        57.0255
# 3                                        29.5785
# 4                                        27.0585
# ..                                           ...
# 455                                      48.2895
# 456                                      62.9895
# 457                                      62.9895
# 458                                      82.8345
# 459                                      15.7395
#
#     PRODUCTVENDOR_PRODUCTVENDOR_LastReceiptDate  \
# 0                                    2011-08-29
# 1                                    2011-08-29
# 2                                    2011-08-29
# 3                                    2011-08-29
# 4                                    2011-08-25
# ..                                          ...
# 455                                  2011-08-27
# 456                                  2011-08-26
# 457                                  2011-08-25
# 458                                  2011-08-29
# 459                                  2011-08-29
#
#      PRODUCTVENDOR_PRODUCTVENDOR_MinOrderQty  \
# 0                                          1
# 1                                          1
# 2                                          1
# 3                                        100
# 4                                        100
# ..                                       ...
# 455                                      100
# 456                                      100
# 457                                      100
# 458                                      100
# 459                                       20
#
#      PRODUCTVENDOR_PRODUCTVENDOR_MaxOrderQty  \
# 0                                          5
# 1                                          5
# 2                                          5
# 3                                       1000
# 4                                       1000
# ..                                       ...
# 455                                     1000
# 456                                     1000
# 457                                     1000
# 458                                     1000
# 459                                      100
#
#      PRODUCTVENDOR_PRODUCTVENDOR_OnOrderQty  \
# 0                                       3.0
# 1                                       3.0
# 2                                       NaN
# 3                                     300.0
# 4                                       NaN
# ..                                      ...
# 455                                     NaN
# 456                                     NaN
# 457                                     NaN
# 458                                     NaN
# 459                                    60.0
#
#      PRODUCTVENDOR_PRODUCTVENDOR_UnitMeasureID  \
# 0                                           12
# 1                                           13
# 2                                           13
# 3                                           16
# 4                                           16
# ..                                         ...
# 455                                         16
# 456                                         16
# 457                                         16
# 458                                         16
# 459                                         15
#
#     PRODUCTVENDOR_PRODUCTVENDOR_datetime_added
# 0                      2024-05-28 09:41:51.953
# 1                      2024-05-28 09:41:51.953
# 2                      2024-05-28 09:41:51.953
# 3                      2024-05-28 09:41:51.953
# 4                      2024-05-28 09:41:51.953
# ..                                         ...
# 455                    2024-05-28 09:41:52.107
# 456                    2024-05-28 09:41:52.107
# 457                    2024-05-28 09:41:52.107
# 458                    2024-05-28 09:41:52.107
# 459                    2024-05-28 09:41:52.107
#
# [460 rows x 12 columns]

# %%
product_query = "SELECT * FROM Product"
products = read_data_return_df(product_query, engine)

products
# Out:
#       PRODUCT_sk  PRODUCT_PRODUCT_ID  PRODUCT_UNITMEASURE_SIZE_ID  \
# 0              1                   1                          NaN
# 1              2                   2                          NaN
# 2              3                   3                          NaN
# 3              4                   4                          NaN
# 4              5                 316                          NaN
# ...          ...                 ...                          ...
# 2068        2069                  73                          NaN
# 2069        2070                  74                          NaN
# 2070        2071                  75                          NaN
# 2071        2072                  76                          NaN
# 2072        2073                  77                          NaN
#
#       PRODUCT_UNITMEASURE_WEIGHT_ID  PRODUCT_PRODUCT_SubCategoryID  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# ...                             ...                            ...
# 2068                            NaN                            NaN
# 2069                            NaN                            NaN
# 2070                            NaN                            NaN
# 2071                            NaN                            NaN
# 2072                            NaN                            NaN
#
#       PRODUCT_PRODUCTSUBCATEGORY_CategoryID  PRODUCT_PRODUCT_ModelID  \
# 0                                       NaN                      NaN
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                                       NaN                      NaN
# 4                                       NaN                      NaN
# ...                                     ...                      ...
# 2068                                    8.0                      NaN
# 2069                                    7.0                      NaN
# 2070                                    1.0                      NaN
# 2071                                    1.0                      NaN
# 2072                                    2.0                      NaN
#
#       PRODUCT_PRODUCTMODELILLUSTRATION_IllustrationID  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 2068                                              NaN
# 2069                                              NaN
# 2070                                              NaN
# 2071                                              NaN
# 2072                                              NaN
#
#       PRODUCT_PRODUCTPRODUCTPHOTO_PhotoID  PRODUCT_PMPDC_DescriptionID  ...  \
# 0                                     1.0                          NaN  ...
# 1                                     1.0                          NaN  ...
# 2                                     1.0                          NaN  ...
# 3                                     1.0                          NaN  ...
# 4                                     1.0                          NaN  ...
# ...                                   ...                          ...  ...
# 2068                                  NaN                          NaN  ...
# 2069                                  NaN                          NaN  ...
# 2070                                  NaN                          NaN  ...
# 2071                                  NaN                          NaN  ...
# 2072                                  NaN                          NaN  ...
#
#                PRODUCT_PRODUCTPHOTO_LargePhotoHexString  \
# 0     0x474946383961F0009500F70000000000800000008000...
# 1     0x474946383961F0009500F70000000000800000008000...
# 2     0x474946383961F0009500F70000000000800000008000...
# 3     0x474946383961F0009500F70000000000800000008000...
# 4     0x474946383961F0009500F70000000000800000008000...
# ...                                                 ...
# 2068                                               None
# 2069                                               None
# 2070                                               None
# 2071                                               None
# 2072                                               None
#
#       PRODUCT_PRODUCTPHOTO_LargePhotoFileName PRODUCT_PRODUCT_SellStartDate  \
# 0                no_image_available_large.gif                    2008-04-30
# 1                no_image_available_large.gif                    2008-04-30
# 2                no_image_available_large.gif                    2008-04-30
# 3                no_image_available_large.gif                    2008-04-30
# 4                no_image_available_large.gif                    2008-04-30
# ...                                       ...                           ...
# 2068                                     None                          None
# 2069                                     None                          None
# 2070                                     None                          None
# 2071                                     None                          None
# 2072                                     None                          None
#
#      PRODUCT_DATE_SellStartDateFK  PRODUCT_PRODUCT_SellEndDate  \
# 0                        20080430                         None
# 1                        20080430                         None
# 2                        20080430                         None
# 3                        20080430                         None
# 4                        20080430                         None
# ...                           ...                          ...
# 2068                     18000101                         None
# 2069                     18000101                         None
# 2070                     18000101                         None
# 2071                     18000101                         None
# 2072                     18000101                         None
#
#       PRODUCT_DATE_SellEndDateFK PRODUCT_PRODUCT_DiscountedDate  \
# 0                       18000101                           None
# 1                       18000101                           None
# 2                       18000101                           None
# 3                       18000101                           None
# 4                       18000101                           None
# ...                          ...                            ...
# 2068                    18000101                           None
# 2069                    18000101                           None
# 2070                    18000101                           None
# 2071                    18000101                           None
# 2072                    18000101                           None
#
#       PRODUCT_DATE_DiscountedDateFK  PRODUCT_PRODUCT_Discontinued  \
# 0                          18000101                           NaN
# 1                          18000101                           NaN
# 2                          18000101                           NaN
# 3                          18000101                           NaN
# 4                          18000101                           NaN
# ...                             ...                           ...
# 2068                       18000101                           0.0
# 2069                       18000101                           0.0
# 2070                       18000101                           0.0
# 2071                       18000101                           0.0
# 2072                       18000101                           0.0
#
#       PRODUCT_datetime_added
# 0    2024-05-28 09:40:29.300
# 1    2024-05-28 09:40:29.317
# 2    2024-05-28 09:40:29.320
# 3    2024-05-28 09:40:29.323
# 4    2024-05-28 09:40:29.330
# ...                      ...
# 2068 2024-05-28 09:40:42.450
# 2069 2024-05-28 09:40:42.453
# 2070 2024-05-28 09:40:42.460
# 2071 2024-05-28 09:40:42.463
# 2072 2024-05-28 09:40:42.467
#
# [2073 rows x 57 columns]

# %%
be_query = "SELECT * FROM BusinessEntity"
business_entities = read_data_return_df(be_query, engine)

business_entities
# Out:
#        BUSINESSENTITY_sk  BUSINESSENTITY_BUSINESSENTITY_BusinessEntityID  \
# 0                      1                                             NaN
# 1                      2                                          1510.0
# 2                      3                                          1518.0
# 3                      4                                          1522.0
# 4                      5                                          1528.0
# ...                  ...                                             ...
# 20889              20890                                         20773.0
# 20890              20891                                         20774.0
# 20891              20892                                         20775.0
# 20892              20893                                         20776.0
# 20893              20894                                         20777.0
#
#        BUSINESSENTITY_BUSINESSENTITYCONTACT_PersonID  \
# 0                                                NaN
# 1                                             1509.0
# 2                                             1517.0
# 3                                             1521.0
# 4                                             1527.0
# ...                                              ...
# 20889                                            NaN
# 20890                                            NaN
# 20891                                            NaN
# 20892                                            NaN
# 20893                                            NaN
#
#        BUSINESSENTITY_CONTACTTYPE_ContactTypeID  \
# 0                                           1.0
# 1                                           2.0
# 2                                           2.0
# 3                                           2.0
# 4                                           2.0
# ...                                         ...
# 20889                                       NaN
# 20890                                       NaN
# 20891                                       NaN
# 20892                                       NaN
# 20893                                       NaN
#
#       BUSINESSENTITY_CONTACTTYPE_Name BUSINESSENTITY_datetime_added
# 0                  Accounting Manager       2024-05-28 09:40:45.607
# 1               Assistant Sales Agent       2024-05-28 09:40:45.607
# 2               Assistant Sales Agent       2024-05-28 09:40:45.607
# 3               Assistant Sales Agent       2024-05-28 09:40:45.607
# 4               Assistant Sales Agent       2024-05-28 09:40:45.607
# ...                               ...                           ...
# 20889                            None       2024-05-28 09:40:48.147
# 20890                            None       2024-05-28 09:40:48.147
# 20891                            None       2024-05-28 09:40:48.147
# 20892                            None       2024-05-28 09:40:48.147
# 20893                            None       2024-05-28 09:40:48.150
#
# [20894 rows x 6 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# combining the customers and business entity data
combined_df = pd.merge(vendors, products,
                           left_on='PRODUCTVENDOR_PRODUCTVENDOR_ProductID',
                           right_on='PRODUCT_PRODUCT_ID')

# dropping the datetime_added and sk columns
drop_columns(combined_df)

combined_df
# Out:
#      PRODUCTVENDOR_PRODUCTVENDOR_ProductID  \
# 0                                        6
# 1                                        6
# 2                                        7
# 3                                        7
# 4                                        8
# ..                                     ...
# 137                                     74
# 138                                     75
# 139                                     75
# 140                                     76
# 141                                     76
#
#      PRODUCTVENDOR_PRODUCTVENDOR_BusinessEntityID  \
# 0                                             855
# 1                                             916
# 2                                             855
# 3                                             916
# 4                                             849
# ..                                            ...
# 137                                           851
# 138                                           893
# 139                                           851
# 140                                           893
# 141                                           851
#
#      PRODUCTVENDOR_PRODUCTVENDOR_AverageLeadTime  \
# 0                                             19
# 1                                             17
# 2                                             19
# 3                                             17
# 4                                             19
# ..                                           ...
# 137                                           16
# 138                                           15
# 139                                           16
# 140                                           15
# 141                                           16
#
#      PRODUCTVENDOR_PRODUCTVENDOR_StandardPrice  \
# 0                                        28.17
# 1                                        25.77
# 2                                        34.38
# 3                                        31.98
# 4                                        44.21
# ..                                         ...
# 137                                      37.21
# 138                                      41.21
# 139                                      35.21
# 140                                      45.28
# 141                                      39.28
#
#      PRODUCTVENDOR_PRODUCTVENDOR_LastReceiptCost  \
# 0                                        29.5785
# 1                                        27.0585
# 2                                        36.0990
# 3                                        33.5790
# 4                                        46.4205
# ..                                           ...
# 137                                      39.0705
# 138                                      43.2705
# 139                                      36.9705
# 140                                      47.5440
# 141                                      41.2440
#
#     PRODUCTVENDOR_PRODUCTVENDOR_LastReceiptDate  \
# 0                                    2011-08-29
# 1                                    2011-08-25
# 2                                    2011-08-29
# 3                                    2011-08-25
# 4                                    2011-08-29
# ..                                          ...
# 137                                  2011-08-04
# 138                                  2011-08-07
# 139                                  2011-08-04
# 140                                  2011-08-07
# 141                                  2011-08-04
#
#      PRODUCTVENDOR_PRODUCTVENDOR_MinOrderQty  \
# 0                                        100
# 1                                        100
# 2                                        100
# 3                                        100
# 4                                        100
# ..                                       ...
# 137                                        1
# 138                                        1
# 139                                        1
# 140                                        1
# 141                                        1
#
#      PRODUCTVENDOR_PRODUCTVENDOR_MaxOrderQty  \
# 0                                       1000
# 1                                       1000
# 2                                       1000
# 3                                       1000
# 4                                       1000
# ..                                       ...
# 137                                        5
# 138                                        5
# 139                                        5
# 140                                        5
# 141                                        5
#
#      PRODUCTVENDOR_PRODUCTVENDOR_OnOrderQty  \
# 0                                     300.0
# 1                                      -1.0
# 2                                      -1.0
# 3                                     300.0
# 4                                     300.0
# ..                                      ...
# 137                                    -1.0
# 138                                    -1.0
# 139                                    -1.0
# 140                                    -1.0
# 141                                    -1.0
#
#      PRODUCTVENDOR_PRODUCTVENDOR_UnitMeasureID  ...  \
# 0                                           16  ...
# 1                                           16  ...
# 2                                           16  ...
# 3                                           16  ...
# 4                                           16  ...
# ..                                         ...  ...
# 137                                         13  ...
# 138                                         13  ...
# 139                                         13  ...
# 140                                         13  ...
# 141                                         13  ...
#
#      PRODUCT_PRODUCT_QuantityPerUnit  PRODUCT_PRODUCT_UnitPrice  \
# 0                     12 - 8 oz jars                      25.00
# 1                     12 - 8 oz jars                      25.00
# 2                    12 - 1 lb pkgs.                      30.00
# 3                    12 - 1 lb pkgs.                      30.00
# 4                    12 - 12 oz jars                      40.00
# ..                               ...                        ...
# 137                        5 kg pkg.                      10.00
# 138               24 - 0.5 l bottles                       7.75
# 139               24 - 0.5 l bottles                       7.75
# 140                           500 ml                      18.00
# 141                           500 ml                      18.00
#
#      PRODUCT_PRODUCT_UnitsOnOrder PRODUCT_PRODUCTCATEGORY_Category  \
# 0                             0.0                       Condiments
# 1                             0.0                       Condiments
# 2                             0.0                          Produce
# 3                             0.0                          Produce
# 4                             0.0                       Condiments
# ..                            ...                              ...
# 137                          20.0                          Produce
# 138                           0.0                        Beverages
# 139                           0.0                        Beverages
# 140                           0.0                        Beverages
# 141                           0.0                        Beverages
#
#                               PRODUCT_CATEGORY_Picture  \
# 0    b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
# 1    b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
# 2    b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
# 3    b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
# 4    b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
# ..                                                 ...
# 137  b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
# 138  b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
# 139  b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
# 140  b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
# 141  b"\x15\x1c/\x00\x02\x00\x00\x00\r\x00\x0e\x00\...
#
#                        PRODUCT_PRODUCTDESCRIPTION_Desc  \
# 0    Sweet and savory sauces, relishes, spreads, an...
# 1    Sweet and savory sauces, relishes, spreads, an...
# 2                            Dried fruit and bean curd
# 3                            Dried fruit and bean curd
# 4    Sweet and savory sauces, relishes, spreads, an...
# ..                                                 ...
# 137                          Dried fruit and bean curd
# 138        Soft drinks, coffees, teas, beers, and ales
# 139        Soft drinks, coffees, teas, beers, and ales
# 140        Soft drinks, coffees, teas, beers, and ales
# 141        Soft drinks, coffees, teas, beers, and ales
#
#      PRODUCT_DATE_SellStartDateFK  PRODUCT_DATE_SellEndDateFK  \
# 0                        18000101                    18000101
# 1                        18000101                    18000101
# 2                        18000101                    18000101
# 3                        18000101                    18000101
# 4                        18000101                    18000101
# ..                            ...                         ...
# 137                      18000101                    18000101
# 138                      18000101                    18000101
# 139                      18000101                    18000101
# 140                      18000101                    18000101
# 141                      18000101                    18000101
#
#     PRODUCT_DATE_DiscountedDateFK PRODUCT_PRODUCT_Discontinued
# 0                        18000101                          0.0
# 1                        18000101                          0.0
# 2                        18000101                          0.0
# 3                        18000101                          0.0
# 4                        18000101                          0.0
# ..                            ...                          ...
# 137                      18000101                          0.0
# 138                      18000101                          0.0
# 139                      18000101                          0.0
# 140                      18000101                          0.0
# 141                      18000101                          0.0
#
# [142 rows x 25 columns]

# %%
# dropping unnecessary columns
columns_to_keep = ['PRODUCTVENDOR_PRODUCTVENDOR_ProductID', 'PRODUCTVENDOR_PRODUCTVENDOR_AverageLeadTime', 'PRODUCTVENDOR_PRODUCTVENDOR_StandardPrice', 'PRODUCTVENDOR_PRODUCTVENDOR_LastReceiptCost', 'PRODUCTVENDOR_PRODUCTVENDOR_MinOrderQty','PRODUCTVENDOR_PRODUCTVENDOR_MaxOrderQty', 'PRODUCTVENDOR_PRODUCTVENDOR_OnOrderQty', 'PRODUCTVENDOR_PRODUCTVENDOR_UnitMeasureID', 'PRODUCT_PRODUCT_UnitPrice']

# converting the string values to integer representations
#combined_df['BUSINESSENTITYADDRESS_ADDRESS_City'] = combined_df['BUSINESSENTITYADDRESS_ADDRESS_City'].astype('category').cat.codes
#combined_df['BUSINESSENTITYADDRESS_ADDRESS_POSTALCODE'] = combined_df['BUSINESSENTITYADDRESS_ADDRESS_POSTALCODE'].astype('category').cat.codes

combined_df = combined_df[columns_to_keep]

combined_df.head()
# Out:
#    PRODUCTVENDOR_PRODUCTVENDOR_ProductID  \
# 0                                      6
# 1                                      6
# 2                                      7
# 3                                      7
# 4                                      8
#
#    PRODUCTVENDOR_PRODUCTVENDOR_AverageLeadTime  \
# 0                                           19
# 1                                           17
# 2                                           19
# 3                                           17
# 4                                           19
#
#    PRODUCTVENDOR_PRODUCTVENDOR_StandardPrice  \
# 0                                      28.17
# 1                                      25.77
# 2                                      34.38
# 3                                      31.98
# 4                                      44.21
#
#    PRODUCTVENDOR_PRODUCTVENDOR_LastReceiptCost  \
# 0                                      29.5785
# 1                                      27.0585
# 2                                      36.0990
# 3                                      33.5790
# 4                                      46.4205
#
#    PRODUCTVENDOR_PRODUCTVENDOR_MinOrderQty  \
# 0                                      100
# 1                                      100
# 2                                      100
# 3                                      100
# 4                                      100
#
#    PRODUCTVENDOR_PRODUCTVENDOR_MaxOrderQty  \
# 0                                     1000
# 1                                     1000
# 2                                     1000
# 3                                     1000
# 4                                     1000
#
#    PRODUCTVENDOR_PRODUCTVENDOR_OnOrderQty  \
# 0                                   300.0
# 1                                    -1.0
# 2                                    -1.0
# 3                                   300.0
# 4                                   300.0
#
#    PRODUCTVENDOR_PRODUCTVENDOR_UnitMeasureID  PRODUCT_PRODUCT_UnitPrice
# 0                                         16                       25.0
# 1                                         16                       25.0
# 2                                         16                       30.0
# 3                                         16                       30.0
# 4                                         16                       40.0

# %% [markdown]
# ## Clustering
# Using Kmeans

# %%
# Define a range of k values to try, from 2 to the number of data points -1 
ks = range(2, combined_df.shape[0])

# Empty list to store the intra- and inter cluster distances
intra_distances = []
inter_distances = []
silhouette_scores = []

for k in ks:
    # Training the KMeans model for this k value
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(combined_df)
    
    # Calculate the intra cluster distance as the sum of the distances of the samples to their closest cluster center. This is done by kmeans.inertia_
    intra_distance = kmeans.inertia_
    intra_distances.append(intra_distance)
    
    # Calculate the inter cluster distance as the mean distance between the cluster centers. this is done by pairwise_distances(kmeans.cluster_centers_)
    cluster_centers = kmeans.cluster_centers_
    inter_distance = np.mean(pairwise_distances(cluster_centers))
    inter_distances.append(inter_distance)
    
    # calculate the silhouette score
    silhouette_scores.append(silhouette_score(combined_df, kmeans.labels_))

# Create a DataFrame with the results
k_df = pd.DataFrame({'k': ks, 'intra_distance': intra_distances, 'inter_distance': inter_distances, 'silhouette_score': silhouette_scores})
k_df
# Out:
# C:\Users\alexb\Desktop\United-Outdoors\venv\Lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (139) found smaller than n_clusters (140). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\alexb\Desktop\United-Outdoors\venv\Lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (139) found smaller than n_clusters (141). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
#        k  intra_distance  inter_distance  silhouette_score
# 0      2    1.251046e+07      980.081987          0.859056
# 1      3    6.257312e+05      920.382500          0.937223
# 2      4    3.327880e+05      822.724354          0.940209
# 3      5    2.106342e+05      866.347984          0.701239
# 4      6    1.189875e+05      829.910372          0.729972
# ..   ...             ...             ...               ...
# 135  137    2.102500e-02      271.356249          0.069658
# 136  138    1.051250e-02      269.832523          0.055953
# 137  139    0.000000e+00      268.348186          0.042254
# 138  140    0.000000e+00      266.785082          0.042254
# 139  141    0.000000e+00      265.184487          0.042254
#
# [140 rows x 4 columns]

# %% [markdown]
# ### Plotting the intra and inter cluster distances

# %%
# Plotting the intra-cluster distances
plt.figure(figsize=(20, 10))
plt.plot(ks, intra_distances, marker='o')
plt.title('Intra-cluster distances for different values of k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Intra-cluster distance (inertia)')
plt.grid(True)
plt.show()

# Plotting the inter-cluster distances
plt.figure(figsize=(20, 10))
plt.plot(ks, inter_distances, marker='o')
plt.title('Inter-cluster distances for different values of k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inter-cluster distance')
plt.grid(True)
plt.show()

# plotting the silhouette scores
plt.figure(figsize=(20, 10))
plt.plot(ks, silhouette_scores, marker='o')
plt.title('Silhouette scores for different values of k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette score')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Finding the optimal number of clusters

# %%
# Gets the index of the maximum silhouette score. Adding 2 because the range of k starts from 2 (since we need at least 2 clusters)
optimal_k = np.argmax(silhouette_scores) + 2

print(f"Optimal number of clusters based on silhouette score: k={optimal_k}")
# Out:
# Optimal number of clusters based on silhouette score: k=4

# %%
# Train a KMeans model with the optimal number of clusters
kmeans_optimal = KMeans(n_clusters=optimal_k)
kmeans_optimal.fit(combined_df)
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# ### Plotting the clusters

# %%
# Defining a list of colors to be used for the clusters
colors = ['deeppink','blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'azure', 'orange', 'brown']

# %%
# Get the cluster assignments for each data point
cluster_assignments = kmeans_optimal.labels_

# Reduce the data to two dimensions using PCA
# PCA is a technique that projects the data into a lower dimensional space while preserving as much variance as possible
pca = PCA(n_components=2) # reducing to 2 dimensions
df_pca = pca.fit_transform(combined_df)

# creating a color map using the colors list
color_map = {label: colors[label % len(colors)] for label in np.unique(cluster_assignments)}

# Map the cluster assignments to colors
color_assignments = list(map(color_map.get, cluster_assignments))

# Create a scatter plot of the reduced data, colored by cluster assignment
plt.figure(figsize=(10, 5))
plt.title('Visualization of clusters')
# PCA is unsupervised, so we don't have labels. We can only label the axes
plt.xlabel('PCA X')
plt.ylabel('PCA Y')

# Create a scatter plot of the reduced data, colored by cluster assignment
scatter = plt.scatter(df_pca[:, 0], df_pca[:, 1], c=np.array(color_assignments))

# Create a legend
handles = [plt.Line2D([],[],marker="o", ls="", color=color_map[i]) for i in np.unique(cluster_assignments)]
plt.legend(handles, np.unique(cluster_assignments), title="Clusters", bbox_to_anchor=(1, 1))

plt.show()

# %%
# Get the unique cluster labels
unique_clusters = np.unique(cluster_assignments)

# Create a figure and a set of subplots
fig, axs = plt.subplots(len(unique_clusters), figsize=(10, 5*len(unique_clusters)))

# Iterate over the unique cluster labels
for i, cluster in enumerate(unique_clusters):
    # Get the data points that belong to this cluster
    cluster_data = df_pca[cluster_assignments == cluster]

    # Create a scatter plot for this cluster using a unique color
    axs[i].scatter(cluster_data[:, 0], cluster_data[:, 1], color=colors[i % len(colors)])
    axs[i].set_title(f'Cluster {cluster}')
    axs[i].set_xlabel('PCA X')
    axs[i].set_ylabel('PCA Y')

# Display the plots
plt.tight_layout()
plt.show()
