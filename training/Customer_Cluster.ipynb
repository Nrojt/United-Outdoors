# %% [markdown]
# # Customer
# Grouping customers in various ways to understand their behavior and preferences.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from common_functions import get_engine, read_data_return_df, drop_sk_datetime_added_columns as drop_columns
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances, silhouette_score
from sklearn.decomposition import PCA

# %% [markdown]
# ## Connecting to the Database

# %%
engine = get_engine()
# Out:
# Connection to UnitedOutdoors database successful

# %% [markdown]
# ## Reading in the Data

# %%
query = "SELECT * FROM Customer"
customers = read_data_return_df(query, engine)

customers
# Out:
#       CUSTOMER_sk  CUSTOMER_CUSTOMER_CustomerID CUSTOMER_CUSTOMER_PersonID  \
# 0               1                             1                       None
# 1               2                             2                       None
# 2               3                             3                       None
# 3               4                             4                       None
# 4               5                             5                       None
# ...           ...                           ...                        ...
# 1331         1332                         30114                       1985
# 1332         1333                         30115                       1987
# 1333         1334                         30116                       1989
# 1334         1335                         30117                       1991
# 1335         1336                         30118                       1993
#
#       CUSTOMER_CUSTOMER_StoreID  CUSTOMER_CUSTOMER_TerritoryID  \
# 0                           934                            144
# 1                          1028                            144
# 2                           642                            136
# 3                           932                            136
# 4                          1026                            136
# ...                         ...                            ...
# 1331                       1986                            134
# 1332                       1988                            118
# 1333                       1990                            136
# 1334                       1992                            136
# 1335                       1994                            140
#
#      CUSTOMER_CUSTOMER_AccountNumber            CUSTOMER_STORE_Name  \
# 0                         AW00000001                   A Bike Store
# 1                         AW00000002             Progressive Sports
# 2                         AW00000003       Advanced Bike Components
# 3                         AW00000004          Modular Cycle Systems
# 4                         AW00000005     Metropolitan Sports Supply
# ...                              ...                            ...
# 1331                      AW00030114           Recreation Toy Store
# 1332                      AW00030115                    Retreat Inn
# 1333                      AW00030116  Technical Parts Manufacturing
# 1334                      AW00030117        Totes & Baskets Company
# 1335                      AW00030118                 World of Bikes
#
#       CUSTOMER_STORE_SalesPersonID  \
# 0                              280
# 1                              283
# 2                              277
# 3                              277
# 4                              281
# ...                            ...
# 1331                           290
# 1332                           282
# 1333                           281
# 1334                           277
# 1335                           277
#
#                             CUSTOMER_STORE_Demographics  \
# 0     <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1     <StoreSurvey xmlns="http://schemas.microsoft.c...
# 2     <StoreSurvey xmlns="http://schemas.microsoft.c...
# 3     <StoreSurvey xmlns="http://schemas.microsoft.c...
# 4     <StoreSurvey xmlns="http://schemas.microsoft.c...
# ...                                                 ...
# 1331  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1332  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1333  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1334  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1335  <StoreSurvey xmlns="http://schemas.microsoft.c...
#
#      CUSTOMER_SALESTERRITORY_Name  ... CUSTOMER_CUSTOMERS_City  \
# 0                       Northwest  ...                    None
# 1                       Northwest  ...                    None
# 2                       Southwest  ...                    None
# 3                       Southwest  ...                    None
# 4                       Southwest  ...                    None
# ...                           ...  ...                     ...
# 1331                       France  ...                    None
# 1332                       Canada  ...                    None
# 1333                    Southwest  ...                    None
# 1334                    Southwest  ...                    None
# 1335                      Central  ...                    None
#
#      CUSTOMER_CUSTOMERS_Region  CUSTOMER_CUSTOMERS_PostalCode  \
# 0                         None                           None
# 1                         None                           None
# 2                         None                           None
# 3                         None                           None
# 4                         None                           None
# ...                        ...                            ...
# 1331                      None                           None
# 1332                      None                           None
# 1333                      None                           None
# 1334                      None                           None
# 1335                      None                           None
#
#       CUSTOMER_CUSTOMERS_Country  CUSTOMER_CUSTOMERS_Phone  \
# 0                           None                      None
# 1                           None                      None
# 2                           None                      None
# 3                           None                      None
# 4                           None                      None
# ...                          ...                       ...
# 1331                        None                      None
# 1332                        None                      None
# 1333                        None                      None
# 1334                        None                      None
# 1335                        None                      None
#
#       CUSTOMER_CUSTOMERS_Fax CUSTOMER_CUSTOMER_Fname CUSTOMER_CUSTOMER_Lname  \
# 0                       None                    None                    None
# 1                       None                    None                    None
# 2                       None                    None                    None
# 3                       None                    None                    None
# 4                       None                    None                    None
# ...                      ...                     ...                     ...
# 1331                    None                    None                    None
# 1332                    None                    None                    None
# 1333                    None                    None                    None
# 1334                    None                    None                    None
# 1335                    None                    None                    None
#
#      CUSTOMER_CUSTOMER_State CUSTOMER_datetime_added
# 0                       None 2024-05-25 08:07:53.263
# 1                       None 2024-05-25 08:07:53.263
# 2                       None 2024-05-25 08:07:53.263
# 3                       None 2024-05-25 08:07:53.263
# 4                       None 2024-05-25 08:07:53.263
# ...                      ...                     ...
# 1331                    None 2024-05-25 08:07:59.580
# 1332                    None 2024-05-25 08:07:59.580
# 1333                    None 2024-05-25 08:07:59.580
# 1334                    None 2024-05-25 08:07:59.580
# 1335                    None 2024-05-25 08:07:59.580
#
# [1336 rows x 30 columns]

# %%
query = "SELECT * FROM BusinessEntity"
business_entity = read_data_return_df(query, engine)

business_entity.head()
# Out:
#    BUSINESSENTITY_sk  BUSINESSENTITY_BUSINESSENTITY_BusinessEntityID  \
# 0                  1                                             NaN
# 1                  2                                          1510.0
# 2                  3                                          1518.0
# 3                  4                                          1522.0
# 4                  5                                          1528.0
#
#    BUSINESSENTITY_BUSINESSENTITYCONTACT_PersonID  \
# 0                                            NaN
# 1                                         1509.0
# 2                                         1517.0
# 3                                         1521.0
# 4                                         1527.0
#
#    BUSINESSENTITY_CONTACTTYPE_ContactTypeID BUSINESSENTITY_CONTACTTYPE_Name  \
# 0                                       1.0              Accounting Manager
# 1                                       2.0           Assistant Sales Agent
# 2                                       2.0           Assistant Sales Agent
# 3                                       2.0           Assistant Sales Agent
# 4                                       2.0           Assistant Sales Agent
#
#   BUSINESSENTITY_datetime_added
# 0       2024-05-25 08:06:16.757
# 1       2024-05-25 08:06:16.757
# 2       2024-05-25 08:06:16.757
# 3       2024-05-25 08:06:16.757
# 4       2024-05-25 08:06:16.757

# %%
query = "SELECT * FROM BusinessEntityAddress"
business_entity_address = read_data_return_df(query, engine)

business_entity_address.head()
# Out:
#    BUSINESSENTITYADDRESS_sk  \
# 0                         1
# 1                         2
# 2                         3
# 3                         4
# 4                         5
#
#    BUSINESSENTITYADDRESS_BUSINESSENTITYADDRESS_BusinessEntityID  \
# 0                                                NaN
# 1                                              111.0
# 2                                              858.0
# 3                                            20787.0
# 4                                              827.0
#
#    BUSINESSENTITYADDRESS_ADDRESSTYPE_AddressTypeID  \
# 0                                                1
# 1                                                2
# 2                                                2
# 3                                                2
# 4                                                2
#
#   BUSINESSENTITYADDRESS_ADDRESSTYPE_Name  \
# 0                                Billing
# 1                                   Home
# 2                                   Home
# 3                                   Home
# 4                                   Home
#
#    BUSINESSENTITYADDRESS_ADDRESS_AddressID  \
# 0                                      NaN
# 1                                      1.0
# 2                                      2.0
# 3                                      3.0
# 4                                      4.0
#
#   BUSINESSENTITYADDRESS_ADDRESS_AddressLine1  \
# 0                                       None
# 1                              1970 Napa Ct.
# 2                         9833 Mt. Dias Blv.
# 3                       7484 Roundtree Drive
# 4                           9539 Glenside Dr
#
#   BUSINESSENTITYADDRESS_ADDRESS_AddressLine2  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
#
#   BUSINESSENTITYADDRESS_ADDRESS_City BUSINESSENTITYADDRESS_ADDRESS_POSTALCODE  \
# 0                               None                                     None
# 1                            Bothell                                    98011
# 2                            Bothell                                    98011
# 3                            Bothell                                    98011
# 4                            Bothell                                    98011
#
#        BUSINESSENTITYADDRESS_ADDRESS_SpatialLocation  \
# 0                                               None
# 1  b'\xe6\x10\x00\x00\x01\x0c\xae\x8b\xfc(\xbc\xe...
# 2  b'\xe6\x10\x00\x00\x01\x0c\xd6\xfa\x85\x1a\xe6...
# 3  b'\xe6\x10\x00\x00\x01\x0c\x18\xe3\x04\xc4\xad...
# 4  b'\xe6\x10\x00\x00\x01\x0c\x81:\r_\x9f\xdeG@\x...
#
#    BUSINESSENTITYADDRESS_ADDRESS_StateProvinceID  \
# 0                                            NaN
# 1                                          145.0
# 2                                          145.0
# 3                                          145.0
# 4                                          145.0
#
#   BUSINESSENTITYADDRESS_datetime_added
# 0              2024-05-25 08:07:17.783
# 1              2024-05-25 08:07:17.783
# 2              2024-05-25 08:07:17.783
# 3              2024-05-25 08:07:17.783
# 4              2024-05-25 08:07:17.783

# %%
query = "SELECT * FROM Territory"
territory = read_data_return_df(query, engine)

territory.head()
# Out:
#    TERRITORY_sk  TERRITORY_REGION_RegionID TERRITORY_REGION_RegionDescription  \
# 0             1                        1.0                            Eastern
# 1             2                        1.0                            Eastern
# 2             3                        1.0                            Eastern
# 3             4                        1.0                            Eastern
# 4             5                        1.0                            Eastern
#
#    TERRITORY_TERRITORIES_TerritoryID  \
# 0                             1581.0
# 1                             1730.0
# 2                             1833.0
# 3                             2116.0
# 4                             2139.0
#
#   TERRITORY_TERRITORIES_TerritoryDescription TERRITORY_REGION_Region  \
# 0                                   Westboro                    None
# 1                                    Bedford                    None
# 2                                  Georgetow                    None
# 3                                     Boston                    None
# 4                                  Cambridge                    None
#
#   TERRITORY_STATE_StateID TERRITORY_STATE_StateName  \
# 0                    None                      None
# 1                    None                      None
# 2                    None                      None
# 3                    None                      None
# 4                    None                      None
#
#   TERRITORY_STATE_StateCapital TERRITORY_STATE_Country  ...  \
# 0                         None                    None  ...
# 1                         None                    None  ...
# 2                         None                    None  ...
# 3                         None                    None  ...
# 4                         None                    None  ...
#
#   TERRITORY_COUNTRYREGION_Name TERRITORY_STATEPROVINCE_StateProvinceID  \
# 0                         None                                     NaN
# 1                         None                                     NaN
# 2                         None                                     NaN
# 3                         None                                     NaN
# 4                         None                                     NaN
#
#    TERRITORY_STATEPROVINCE_StateProvinceCode  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
#
#   TERRITORY_STATEPROVINCE_IsOnlyStateProvinceFlag  \
# 0                                            None
# 1                                            None
# 2                                            None
# 3                                            None
# 4                                            None
#
#   TERRITORY_STATEPROVINCE_Name TERRITORY_SALESTAXRATE_SalesTaxRateID  \
# 0                         None                                   NaN
# 1                         None                                   NaN
# 2                         None                                   NaN
# 3                         None                                   NaN
# 4                         None                                   NaN
#
#    TERRITORY_SALESTAXRATE_TaxType TERRITORY_SALESTAXRATE_TaxRate  \
# 0                            None                            NaN
# 1                            None                            NaN
# 2                            None                            NaN
# 3                            None                            NaN
# 4                            None                            NaN
#
#    TERRITORY_SALESTAXRATE_Name TERRITORY_datetime_added
# 0                         None  2024-05-25 08:07:15.400
# 1                         None  2024-05-25 08:07:15.400
# 2                         None  2024-05-25 08:07:15.400
# 3                         None  2024-05-25 08:07:15.400
# 4                         None  2024-05-25 08:07:15.400
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# combining the customers and business entity data
combined_df = pd.merge(customers, business_entity, left_on='CUSTOMER_CUSTOMER_CustomerID', right_on='BUSINESSENTITY_BUSINESSENTITY_BusinessEntityID', suffixes=('_customer', '_business_entity')) 

combined_df = pd.merge(combined_df, business_entity_address, left_on='BUSINESSENTITY_sk', right_on='BUSINESSENTITYADDRESS_BUSINESSENTITYADDRESS_BusinessEntityID', suffixes=('', '_business_entity_address'))

combined_df = pd.merge(combined_df, territory, left_on='CUSTOMER_CUSTOMER_TerritoryID', right_on='TERRITORY_sk', suffixes=('', '_territory'))

# dropping the datetime_added and sk columns
drop_columns(combined_df)

# %%
# dropping unnecessary columns
columns_to_keep = ['CUSTOMER_CUSTOMER_CustomerID', 'CUSTOMER_CUSTOMER_StoreID', 'CUSTOMER_CUSTOMER_TerritoryID', 'CUSTOMER_STORE_SalesPersonID', 'CUSTOMER_SALESTERRITORY_CountryRegionCode','CUSTOMER_SALESTERRITORY_SalesYTD', 'CUSTOMER_SALESTERRITORY_SalesLastYear', 'BUSINESSENTITY_CONTACTTYPE_ContactTypeID', 'BUSINESSENTITYADDRESS_ADDRESSTYPE_AddressTypeID', 'TERRITORY_TERRITORIES_TerritoryID', 'TERRITORY_STATEPROVINCE_StateProvinceID', 'TERRITORY_STATEPROVINCE_IsOnlyStateProvinceFlag', 'TERRITORY_SALESTAXRATE_SalesTaxRateID', 'BUSINESSENTITYADDRESS_ADDRESS_City', 'BUSINESSENTITYADDRESS_ADDRESS_POSTALCODE']

# converting the string values to integer representations
combined_df['BUSINESSENTITYADDRESS_ADDRESS_City'] = combined_df['BUSINESSENTITYADDRESS_ADDRESS_City'].astype('category').cat.codes
combined_df['BUSINESSENTITYADDRESS_ADDRESS_POSTALCODE'] = combined_df['BUSINESSENTITYADDRESS_ADDRESS_POSTALCODE'].astype('category').cat.codes

combined_df = combined_df[columns_to_keep]

combined_df.head()
# Out:
#    CUSTOMER_CUSTOMER_CustomerID  CUSTOMER_CUSTOMER_StoreID  \
# 0                           292                        496
# 1                           294                        396
# 2                           296                        766
# 3                           298                       1488
# 4                           300                        386
#
#    CUSTOMER_CUSTOMER_TerritoryID  CUSTOMER_STORE_SalesPersonID  \
# 0                            136                           277
# 1                            136                           276
# 2                            138                           279
# 3                            118                           282
# 4                            118                           278
#
#   CUSTOMER_SALESTERRITORY_CountryRegionCode  CUSTOMER_SALESTERRITORY_SalesYTD  \
# 0                                       136                      1.051085e+07
# 1                                       136                      1.051085e+07
# 2                                       136                      2.538667e+06
# 3                                       118                      6.771829e+06
# 4                                       118                      6.771829e+06
#
#    CUSTOMER_SALESTERRITORY_SalesLastYear  \
# 0                           5.366576e+06
# 1                           5.366576e+06
# 2                           3.925071e+06
# 3                           5.693989e+06
# 4                           5.693989e+06
#
#    BUSINESSENTITY_CONTACTTYPE_ContactTypeID  \
# 0                                      11.0
# 1                                      11.0
# 2                                      11.0
# 3                                      11.0
# 4                                      11.0
#
#    BUSINESSENTITYADDRESS_ADDRESSTYPE_AddressTypeID  \
# 0                                                3
# 1                                                3
# 2                                                3
# 3                                                3
# 4                                                3
#
#    TERRITORY_TERRITORIES_TerritoryID  TERRITORY_STATEPROVINCE_StateProvinceID  \
# 0                                4.0                                      6.0
# 1                                4.0                                      6.0
# 2                                5.0                                     15.0
# 3                                6.0                                      1.0
# 4                                6.0                                      1.0
#
#   TERRITORY_STATEPROVINCE_IsOnlyStateProvinceFlag  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    TERRITORY_SALESTAXRATE_SalesTaxRateID  BUSINESSENTITYADDRESS_ADDRESS_City  \
# 0                                   18.0                                  67
# 1                                   18.0                                 126
# 2                                   20.0                                  10
# 3                                    1.0                                  62
# 4                                    1.0                                 101
#
#    BUSINESSENTITYADDRESS_ADDRESS_POSTALCODE
# 0                                        33
# 1                                       100
# 2                                        61
# 3                                        45
# 4                                        14

# %% [markdown]
# ## Clustering
# Using Kmeans

# %%
# Define a range of k values to try, from 2 to the number of data points -1 
ks = range(2, combined_df.shape[0])

# Empty list to store the intra- and inter cluster distances
intra_distances = []
inter_distances = []
silhouette_scores = []

for k in ks:
    # Training the KMeans model for this k value
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(combined_df)
    
    # Calculate the intra cluster distance as the sum of the distances of the samples to their closest cluster center. This is done by kmeans.inertia_
    intra_distance = kmeans.inertia_
    intra_distances.append(intra_distance)
    
    # Calculate the inter cluster distance as the mean distance between the cluster centers. this is done by pairwise_distances(kmeans.cluster_centers_)
    cluster_centers = kmeans.cluster_centers_
    inter_distance = np.mean(pairwise_distances(cluster_centers))
    inter_distances.append(inter_distance)
    
    # calculate the silhouette score
    silhouette_scores.append(silhouette_score(combined_df, kmeans.labels_))

# Create a DataFrame with the results
k_df = pd.DataFrame({'k': ks, 'intra_distance': intra_distances, 'inter_distance': inter_distances, 'silhouette_score': silhouette_scores})
k_df
# Out:
#        k  intra_distance  inter_distance  silhouette_score
# 0      2    4.935856e+14    2.605630e+06          0.631841
# 1      3    3.174251e+14    2.950578e+06          0.651506
# 2      4    1.247081e+14    3.657532e+06          0.753034
# 3      5    3.846661e+13    3.578408e+06          0.855733
# 4      6    1.978217e+13    3.642568e+06          0.865266
# ..   ...             ...             ...               ...
# 164  166    2.790000e+02    3.685433e+06          0.056506
# 165  167    8.000000e+00    3.703087e+06          0.046323
# 166  168    6.000000e+00    3.698121e+06          0.034740
# 167  169    4.000000e+00    3.694550e+06          0.023210
# 168  170    2.000000e+00    3.688479e+06          0.011565
#
# [169 rows x 4 columns]

# %% [markdown]
# ### Plotting the intra and inter cluster distances

# %%
# Plotting the intra-cluster distances
plt.figure(figsize=(20, 10))
plt.plot(ks, intra_distances, marker='o')
plt.title('Intra-cluster distances for different values of k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Intra-cluster distance (inertia)')
plt.grid(True)
plt.show()

# Plotting the inter-cluster distances
plt.figure(figsize=(20, 10))
plt.plot(ks, inter_distances, marker='o')
plt.title('Inter-cluster distances for different values of k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inter-cluster distance')
plt.grid(True)
plt.show()

# plotting the silhouette scores
plt.figure(figsize=(20, 10))
plt.plot(ks, silhouette_scores, marker='o')
plt.title('Silhouette scores for different values of k')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette score')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Finding the optimal number of clusters

# %%
# Gets the index of the maximum silhouette score. Adding 2 because the range of k starts from 2 (since we need at least 2 clusters)
optimal_k = np.argmax(silhouette_scores) + 2

print(f"Optimal number of clusters based on silhouette score: k={optimal_k}")
# Out:
# Optimal number of clusters based on silhouette score: k=10

# %%
# Train a KMeans model with the optimal number of clusters
kmeans_optimal = KMeans(n_clusters=optimal_k)
kmeans_optimal.fit(combined_df)
# Out:
# KMeans(n_clusters=10)

# %% [markdown]
# ### Plotting the clusters

# %%
# Defining a list of colors to be used for the clusters
colors = ['deeppink','blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'azure', 'orange', 'brown']

# %%
# Get the cluster assignments for each data point
cluster_assignments = kmeans_optimal.labels_

# Reduce the data to two dimensions using PCA
# PCA is a technique that projects the data into a lower dimensional space while preserving as much variance as possible
pca = PCA(n_components=2) # reducing to 2 dimensions
df_pca = pca.fit_transform(combined_df)

# creating a color map using the colors list
color_map = {label: colors[label % len(colors)] for label in np.unique(cluster_assignments)}

# Map the cluster assignments to colors
color_assignments = list(map(color_map.get, cluster_assignments))

# Create a scatter plot of the reduced data, colored by cluster assignment
plt.figure(figsize=(10, 5))
plt.title('Visualization of clusters')
# PCA is unsupervised, so we don't have labels. We can only label the axes
plt.xlabel('PCA X')
plt.ylabel('PCA Y')

# Create a scatter plot of the reduced data, colored by cluster assignment
scatter = plt.scatter(df_pca[:, 0], df_pca[:, 1], c=np.array(color_assignments))

# Create a legend
handles = [plt.Line2D([],[],marker="o", ls="", color=color_map[i]) for i in np.unique(cluster_assignments)]
plt.legend(handles, np.unique(cluster_assignments), title="Clusters", bbox_to_anchor=(1, 1))

plt.show()

# %%
# Get the unique cluster labels
unique_clusters = np.unique(cluster_assignments)

# Create a figure and a set of subplots
fig, axs = plt.subplots(len(unique_clusters), figsize=(10, 5*len(unique_clusters)))

# Iterate over the unique cluster labels
for i, cluster in enumerate(unique_clusters):
    # Get the data points that belong to this cluster
    cluster_data = df_pca[cluster_assignments == cluster]

    # Create a scatter plot for this cluster using a unique color
    axs[i].scatter(cluster_data[:, 0], cluster_data[:, 1], color=colors[i % len(colors)])
    axs[i].set_title(f'Cluster {cluster}')
    axs[i].set_xlabel('PCA X')
    axs[i].set_ylabel('PCA Y')

# Display the plots
plt.tight_layout()
plt.show()
